# %% [markdown]
# ## sequence_list.csvの作成

# %%
import subprocess

result = subprocess.run(["ruby", "create_list.rb"], capture_output=True, text=True)
print(result.stdout)  # Rubyスクリプトの標準出力を表示

# エラー出力を表示
print("STDOUT:", result.stdout)
print("STDERR:", result.stderr)
# Out:
# STDOUT:
# STDERR:

# %%
import pandas as pd

data_file = 'sequence_list.csv'

# %% [markdown]
# # フォルダ毎の数列の数

# %%
df = pd.read_csv(data_file)
df.columns = ['no', 'seq_no']
df = df[['seq_no']]
df['seq_no'] = df['seq_no'] // 1000
df
# Out:
#       seq_no
# 0        200
# 1        200
# 2        200
# 3        200
# 4        200
# ...      ...
# 2048     299
# 2049     299
# 2050     299
# 2051     299
# 2052     299
#
# [2053 rows x 1 columns]

# %%
# show_rangeの開始に注意
show_range = list(range(199, 299+1))
df.plot.hist(bins=show_range)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# ヒストグラムの度数分布表を作成
hist = pd.cut(df['seq_no'], bins=show_range).value_counts().sort_index()

# 度数分布表を表示（ただし、度数が0は除く）
print('度数分布表')

cnt = 0
for i in hist.index:
    cnt += 1
    if i.right % 10 == 0:
        print()
    print(f'{i.right} : {hist[i]}', end=', ')

print()
print(f'合計 : {cnt}')
# Out:
# 度数分布表
#
# 200 : 9, 201 : 12, 202 : 7, 203 : 4, 204 : 4, 205 : 4, 206 : 11, 207 : 2, 208 : 30, 209 : 7,
# 210 : 6, 211 : 6, 212 : 17, 213 : 25, 214 : 11, 215 : 13, 216 : 15, 217 : 9, 218 : 22, 219 : 9,
# 220 : 5, 221 : 2, 222 : 5, 223 : 5, 224 : 10, 225 : 38, 226 : 24, 227 : 14, 228 : 13, 229 : 12,
# 230 : 8, 231 : 3, 232 : 5, 233 : 1, 234 : 5, 235 : 6, 236 : 15, 237 : 20, 238 : 8, 239 : 2,
# 240 : 4, 241 : 0, 242 : 9, 243 : 13, 244 : 5, 245 : 6, 246 : 10, 247 : 9, 248 : 10, 249 : 6,
# 250 : 5, 251 : 1, 252 : 3, 253 : 5, 254 : 2, 255 : 6, 256 : 3, 257 : 2, 258 : 7, 259 : 9,
# 260 : 6, 261 : 14, 262 : 11, 263 : 3, 264 : 7, 265 : 5, 266 : 5, 267 : 2, 268 : 7, 269 : 13,
# 270 : 6, 271 : 24, 272 : 28, 273 : 17, 274 : 18, 275 : 18, 276 : 59, 277 : 35, 278 : 23, 279 : 18,
# 280 : 24, 281 : 34, 282 : 84, 283 : 74, 284 : 57, 285 : 57, 286 : 36, 287 : 12, 288 : 63, 289 : 106,
# 290 : 58, 291 : 64, 292 : 96, 293 : 116, 294 : 132, 295 : 64, 296 : 17, 297 : 26, 298 : 18, 299 : 51,
# 合計 : 100

# %% [markdown]
# # 偏り

# %%
df = pd.read_csv(data_file)
df.columns = ['no', 'seq_no']
df = df[['seq_no']]
df['seq_no'] = df['seq_no'] % 100
df
# Out:
#       seq_no
# 0         74
# 1         75
# 2         60
# 3         19
# 4         25
# ...      ...
# 2048      54
# 2049      55
# 2050      58
# 2051      93
# 2052      94
#
# [2053 rows x 1 columns]

# %%
df.plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>
